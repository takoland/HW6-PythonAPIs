# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import urllib

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %%
# OpenWeatherMap API Key
api_key = "25bc90a1196e6f153eece0bc0b0fc9eb"

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + urllib.request.pathname2url(city)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(city_url)

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hobart
# Processing Record 2 of Set 1 | caluquembe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=caluquembe
# Processing Record 3 of Set 1 | asfi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=asfi
# City not found. Skipping...
# Processing Record 4 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kapaa
# Processing Record 5 of Set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-philippe
# Processing Record 6 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=qaanaaq
# Processing Record 7 of Set 1 | ocala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ocala
# Processing Record 8 of Set 1 | panguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=panguna
# Processing Record 9 of Set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=carnarvon
# Processing Record 10 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=port%20alfred
# Processing Record 11 of Set 1 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=iqaluit
# Processing Record 12 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bluff
# Processing Record 13 of Set 1 | khandbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=khandbari
# Processing Record 14 of Set 1 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pevek
# Processing Record 15 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=atuona
# Processing Record 16 of Set 1 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mount%20isa
# Processing Record 17 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=arraial%20do%20cabo
# Processing Record 18 of Set 1 | millerovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=millerovo
# Processing Record 19 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=butaritari
# Processing Record 20 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hermanus
# Processing Record 21 of Set 1 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=havre-saint-pierre
# Processing Record 22 of Set 1 | oistins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=oistins
# Processing Record 23 of Set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=severo-kurilsk
# Processing Record 24 of Set 1 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=port-gentil
# Processing Record 25 of Set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mar%20del%20plata
# Processing Record 26 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=punta%20arenas
# Processing Record 27 of Set 1 | the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=the%20valley
# Processing Record 28 of Set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 1 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=faya
# Processing Record 30 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rikitea
# Processing Record 31 of Set 1 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=avera
# Processing Record 32 of Set 1 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=samusu
# City not found. Skipping...
# Processing Record 33 of Set 1 | labutta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=labutta
# City not found. Skipping...
# Processing Record 34 of Set 1 | mackenzie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mackenzie
# Processing Record 35 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=albany
# Processing Record 36 of Set 1 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bathsheba
# Processing Record 37 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bredasdorp
# Processing Record 38 of Set 1 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mogadishu
# Processing Record 39 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ushuaia
# Processing Record 40 of Set 1 | cocobeach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cocobeach
# Processing Record 41 of Set 1 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nanortalik
# Processing Record 42 of Set 1 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chuy
# Processing Record 43 of Set 1 | terrace
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=terrace
# Processing Record 44 of Set 1 | cootamundra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cootamundra
# Processing Record 45 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=busselton
# Processing Record 46 of Set 1 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saldanha
# Processing Record 47 of Set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ahipara
# Processing Record 49 of Set 1 | thiruvananthapuram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=thiruvananthapuram
# Processing Record 50 of Set 1 | vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vila
# Processing Record 0 of Set 2 | chumikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chumikan
# Processing Record 1 of Set 2 | pimenta bueno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pimenta%20bueno
# Processing Record 2 of Set 2 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saskylakh
# Processing Record 3 of Set 2 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tuktoyaktuk
# Processing Record 4 of Set 2 | ekibastuz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ekibastuz
# Processing Record 5 of Set 2 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=barrow
# Processing Record 6 of Set 2 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kahului
# Processing Record 7 of Set 2 | latacunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=latacunga
# Processing Record 8 of Set 2 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=paamiut
# Processing Record 9 of Set 2 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mataura
# Processing Record 10 of Set 2 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hamilton
# Processing Record 11 of Set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tasiilaq
# Processing Record 12 of Set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hilo
# Processing Record 13 of Set 2 | halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=halifax
# Processing Record 14 of Set 2 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=alta%20floresta
# Processing Record 15 of Set 2 | dekar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dekar
# Processing Record 16 of Set 2 | port moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=port%20moresby
# Processing Record 17 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cape%20town
# Processing Record 18 of Set 2 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=torbay
# Processing Record 19 of Set 2 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=leningradskiy
# Processing Record 20 of Set 2 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vaini
# Processing Record 21 of Set 2 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=aklavik
# Processing Record 22 of Set 2 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=port%20elizabeth
# Processing Record 23 of Set 2 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kavieng
# Processing Record 24 of Set 2 | riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=riyadh
# Processing Record 25 of Set 2 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tiksi
# Processing Record 26 of Set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=yellowknife
# Processing Record 27 of Set 2 | syasstroy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=syasstroy
# Processing Record 28 of Set 2 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 2 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=victoria
# Processing Record 30 of Set 2 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=airai
# Processing Record 31 of Set 2 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cidreira
# Processing Record 32 of Set 2 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=adrar
# Processing Record 33 of Set 2 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hami
# Processing Record 34 of Set 2 | kassala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kassala
# Processing Record 35 of Set 2 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=acapulco
# Processing Record 36 of Set 2 | camana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=camana
# City not found. Skipping...
# Processing Record 37 of Set 2 | ito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ito
# Processing Record 38 of Set 2 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=portland
# Processing Record 39 of Set 2 | warqla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=warqla
# City not found. Skipping...
# Processing Record 40 of Set 2 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint%20anthony
# Processing Record 41 of Set 2 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=marcona
# City not found. Skipping...
# Processing Record 42 of Set 2 | moissala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=moissala
# Processing Record 43 of Set 2 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kavaratti
# Processing Record 44 of Set 2 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=faanui
# Processing Record 45 of Set 2 | mamlyutka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mamlyutka
# Processing Record 46 of Set 2 | navahrudak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=navahrudak
# Processing Record 47 of Set 2 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=havoysund
# Processing Record 48 of Set 2 | jiuquan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jiuquan
# Processing Record 49 of Set 2 | gushikawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=gushikawa
# Processing Record 0 of Set 3 | mwinilunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mwinilunga
# Processing Record 1 of Set 3 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=grand%20river%20south%20east
# City not found. Skipping...
# Processing Record 2 of Set 3 | les escoumins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=les%20escoumins
# Processing Record 3 of Set 3 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=fortuna
# Processing Record 4 of Set 3 | erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=erzin
# Processing Record 5 of Set 3 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=amderma
# City not found. Skipping...
# Processing Record 6 of Set 3 | fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=fare
# Processing Record 7 of Set 3 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tuatapere
# Processing Record 8 of Set 3 | dunayivtsi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dunayivtsi
# City not found. Skipping...
# Processing Record 9 of Set 3 | coruripe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=coruripe
# Processing Record 10 of Set 3 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pisco
# Processing Record 11 of Set 3 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=goderich
# Processing Record 12 of Set 3 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=anadyr
# Processing Record 13 of Set 3 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saleaula
# City not found. Skipping...
# Processing Record 14 of Set 3 | temiscaming
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=temiscaming
# Processing Record 15 of Set 3 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=yulara
# Processing Record 16 of Set 3 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ilulissat
# Processing Record 17 of Set 3 | villa carlos paz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=villa%20carlos%20paz
# Processing Record 18 of Set 3 | kaspiyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kaspiyskiy
# Processing Record 19 of Set 3 | mehran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mehran
# Processing Record 20 of Set 3 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hithadhoo
# Processing Record 21 of Set 3 | tynda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tynda
# Processing Record 22 of Set 3 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cherskiy
# Processing Record 23 of Set 3 | kyshtovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kyshtovka
# Processing Record 24 of Set 3 | epernay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=epernay
# Processing Record 25 of Set 3 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 3 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=broome
# Processing Record 27 of Set 3 | lora del rio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lora%20del%20rio
# Processing Record 28 of Set 3 | flagstaff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=flagstaff
# Processing Record 29 of Set 3 | grand centre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=grand%20centre
# City not found. Skipping...
# Processing Record 30 of Set 3 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bambous%20virieux
# Processing Record 31 of Set 3 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kaitangata
# Processing Record 32 of Set 3 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=meulaboh
# Processing Record 33 of Set 3 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=avarua
# Processing Record 34 of Set 3 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=naze
# Processing Record 35 of Set 3 | koster
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=koster
# Processing Record 36 of Set 3 | verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=verkhnevilyuysk
# Processing Record 37 of Set 3 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=puerto%20ayora
# Processing Record 38 of Set 3 | deep river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=deep%20river
# Processing Record 39 of Set 3 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chokurdakh
# Processing Record 40 of Set 3 | melita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=melita
# Processing Record 41 of Set 3 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=provideniya
# Processing Record 42 of Set 3 | muisne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=muisne
# Processing Record 43 of Set 3 | jiexiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jiexiu
# Processing Record 44 of Set 3 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 3 | boffa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=boffa
# Processing Record 46 of Set 3 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=komsomolskiy
# Processing Record 47 of Set 3 | knysna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=knysna
# Processing Record 48 of Set 3 | vilhena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vilhena
# Processing Record 49 of Set 3 | dolbeau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dolbeau
# City not found. Skipping...
# Processing Record 0 of Set 4 | ashland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ashland
# Processing Record 1 of Set 4 | la palma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=la%20palma
# Processing Record 2 of Set 4 | la asuncion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=la%20asuncion
# Processing Record 3 of Set 4 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lorengau
# Processing Record 4 of Set 4 | bluefields
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bluefields
# Processing Record 5 of Set 4 | colares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=colares
# Processing Record 6 of Set 4 | new glasgow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=new%20glasgow
# Processing Record 7 of Set 4 | klyuchi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=klyuchi
# Processing Record 8 of Set 4 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=taltal
# Processing Record 9 of Set 4 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 4 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=khatanga
# Processing Record 11 of Set 4 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=new%20norfolk
# Processing Record 12 of Set 4 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=belushya%20guba
# City not found. Skipping...
# Processing Record 13 of Set 4 | aloleng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=aloleng
# Processing Record 14 of Set 4 | wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=wanning
# Processing Record 15 of Set 4 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vostok
# Processing Record 16 of Set 4 | doctor pedro p. pena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=doctor%20pedro%20p.%20pena
# City not found. Skipping...
# Processing Record 17 of Set 4 | kittery
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kittery
# Processing Record 18 of Set 4 | kargasok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kargasok
# Processing Record 19 of Set 4 | san carlos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=san%20carlos
# Processing Record 20 of Set 4 | vigrestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vigrestad
# Processing Record 21 of Set 4 | gurskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=gurskoye
# City not found. Skipping...
# Processing Record 22 of Set 4 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=port%20lincoln
# Processing Record 23 of Set 4 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=east%20london
# Processing Record 24 of Set 4 | nacala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nacala
# Processing Record 25 of Set 4 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cayenne
# Processing Record 26 of Set 4 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ketchikan
# Processing Record 27 of Set 4 | gimli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=gimli
# Processing Record 28 of Set 4 | nioro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nioro
# Processing Record 29 of Set 4 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kruisfontein
# Processing Record 30 of Set 4 | cross lanes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cross%20lanes
# Processing Record 31 of Set 4 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=taoudenni
# Processing Record 32 of Set 4 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 4 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=narsaq
# Processing Record 34 of Set 4 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=san%20patricio
# Processing Record 35 of Set 4 | evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=evensk
# Processing Record 36 of Set 4 | boda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=boda
# Processing Record 37 of Set 4 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=takoradi
# Processing Record 38 of Set 4 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tura
# Processing Record 39 of Set 4 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jamestown
# Processing Record 40 of Set 4 | lolua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lolua
# City not found. Skipping...
# Processing Record 41 of Set 4 | quime
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=quime
# Processing Record 42 of Set 4 | suluq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=suluq
# Processing Record 43 of Set 4 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nelson%20bay
# Processing Record 44 of Set 4 | san juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=san%20juan
# Processing Record 45 of Set 4 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sao%20filipe
# Processing Record 46 of Set 4 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=clyde%20river
# Processing Record 47 of Set 4 | santa vitoria do palmar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=santa%20vitoria%20do%20palmar
# Processing Record 48 of Set 4 | bassar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bassar
# Processing Record 49 of Set 4 | thaton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=thaton
# Processing Record 0 of Set 5 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lavrentiya
# Processing Record 1 of Set 5 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=salinopolis
# Processing Record 2 of Set 5 | college station
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=college%20station
# Processing Record 3 of Set 5 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=castro
# Processing Record 4 of Set 5 | bayir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bayir
# Processing Record 5 of Set 5 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ponta%20do%20sol
# Processing Record 6 of Set 5 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sabang
# Processing Record 7 of Set 5 | valleyview
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=valleyview
# Processing Record 8 of Set 5 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hambantota
# Processing Record 9 of Set 5 | atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=atambua
# Processing Record 10 of Set 5 | twante
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=twante
# Processing Record 11 of Set 5 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=zhigansk
# Processing Record 12 of Set 5 | kapoeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kapoeta
# City not found. Skipping...
# Processing Record 13 of Set 5 | dostpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dostpur
# Processing Record 14 of Set 5 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vardo
# Processing Record 15 of Set 5 | pacanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pacanga
# Processing Record 16 of Set 5 | basco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=basco
# Processing Record 17 of Set 5 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=coquimbo
# Processing Record 18 of Set 5 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mahebourg
# Processing Record 19 of Set 5 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=beloha
# Processing Record 20 of Set 5 | manaira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=manaira
# Processing Record 21 of Set 5 | biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=biak
# Processing Record 22 of Set 5 | zlobin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=zlobin
# Processing Record 23 of Set 5 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ribeira%20grande
# Processing Record 24 of Set 5 | brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=brae
# Processing Record 25 of Set 5 | kisumu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kisumu
# Processing Record 26 of Set 5 | punuare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=punuare
# Processing Record 27 of Set 5 | puerto narino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=puerto%20narino
# Processing Record 28 of Set 5 | dongying
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dongying
# Processing Record 29 of Set 5 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=araouane
# Processing Record 30 of Set 5 | nanakuli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nanakuli
# Processing Record 31 of Set 5 | sabha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sabha
# Processing Record 32 of Set 5 | clifton springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=clifton%20springs
# Processing Record 33 of Set 5 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=buala
# Processing Record 34 of Set 5 | maghama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=maghama
# City not found. Skipping...
# Processing Record 35 of Set 5 | kifri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kifri
# Processing Record 36 of Set 5 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dikson
# Processing Record 37 of Set 5 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=esperance
# Processing Record 38 of Set 5 | formosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=formosa
# Processing Record 39 of Set 5 | san carlos de bariloche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=san%20carlos%20de%20bariloche
# Processing Record 40 of Set 5 | toliary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=toliary
# City not found. Skipping...
# Processing Record 41 of Set 5 | dawlatabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dawlatabad
# Processing Record 42 of Set 5 | yinchuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=yinchuan
# Processing Record 43 of Set 5 | mahesana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mahesana
# Processing Record 44 of Set 5 | muroto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=muroto
# Processing Record 45 of Set 5 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hervey%20bay
# Processing Record 46 of Set 5 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hasaki
# Processing Record 47 of Set 5 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=alofi
# Processing Record 48 of Set 5 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=comodoro%20rivadavia
# Processing Record 49 of Set 5 | naigarhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=naigarhi
# Processing Record 0 of Set 6 | north bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=north%20bend
# Processing Record 1 of Set 6 | saint-denis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-denis
# Processing Record 2 of Set 6 | jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jalu
# Processing Record 3 of Set 6 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=srednekolymsk
# Processing Record 4 of Set 6 | chipinge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chipinge
# Processing Record 5 of Set 6 | chiredzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chiredzi
# Processing Record 6 of Set 6 | almaznyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=almaznyy
# Processing Record 7 of Set 6 | vilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vilyuysk
# Processing Record 8 of Set 6 | kundiawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kundiawa
# Processing Record 9 of Set 6 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=flinders
# Processing Record 10 of Set 6 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-pierre
# Processing Record 11 of Set 6 | dzhubga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dzhubga
# Processing Record 12 of Set 6 | hope
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hope
# Processing Record 13 of Set 6 | galle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=galle
# Processing Record 14 of Set 6 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=deputatskiy
# Processing Record 15 of Set 6 | finschhafen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=finschhafen
# Processing Record 16 of Set 6 | pangoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pangoa
# Processing Record 17 of Set 6 | coos bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=coos%20bay
# Processing Record 18 of Set 6 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=henties%20bay
# Processing Record 19 of Set 6 | nuevo progreso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nuevo%20progreso
# Processing Record 20 of Set 6 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=los%20llanos%20de%20aridane
# Processing Record 21 of Set 6 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=port-cartier
# Processing Record 22 of Set 6 | mullaitivu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mullaitivu
# City not found. Skipping...
# Processing Record 23 of Set 6 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hofn
# Processing Record 24 of Set 6 | sokolo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sokolo
# Processing Record 25 of Set 6 | puerto ayacucho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=puerto%20ayacucho
# Processing Record 26 of Set 6 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=namibe
# Processing Record 27 of Set 6 | ballitoville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ballitoville
# Processing Record 28 of Set 6 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=katsuura
# Processing Record 29 of Set 6 | dundee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dundee
# Processing Record 30 of Set 6 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=codrington
# Processing Record 31 of Set 6 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=aykhal
# Processing Record 32 of Set 6 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 6 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=norman%20wells
# Processing Record 34 of Set 6 | borogontsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=borogontsy
# Processing Record 35 of Set 6 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=souillac
# Processing Record 36 of Set 6 | kushiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kushiro
# Processing Record 37 of Set 6 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=longyearbyen
# Processing Record 38 of Set 6 | mercedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mercedes
# Processing Record 39 of Set 6 | high level
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=high%20level
# Processing Record 40 of Set 6 | keetmanshoop
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=keetmanshoop
# Processing Record 41 of Set 6 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sur
# Processing Record 42 of Set 6 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=prince%20rupert
# Processing Record 43 of Set 6 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bengkulu
# City not found. Skipping...
# Processing Record 44 of Set 6 | arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=arman
# Processing Record 45 of Set 6 | gurlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=gurlan
# Processing Record 46 of Set 6 | chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chicama
# Processing Record 47 of Set 6 | beroroha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=beroroha
# Processing Record 48 of Set 6 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hobyo
# Processing Record 49 of Set 6 | paradwip
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=paradwip
# City not found. Skipping...
# Processing Record 0 of Set 7 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dingle
# Processing Record 1 of Set 7 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mys%20shmidta
# City not found. Skipping...
# Processing Record 2 of Set 7 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ancud
# Processing Record 3 of Set 7 | kazachinskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kazachinskoye
# Processing Record 4 of Set 7 | pochutla
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=gambela
# Processing Record 28 of Set 11 | vaitape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vaitape
# Processing Record 29 of Set 11 | aleksandrovsk-sakhalinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=aleksandrovsk-sakhalinskiy
# Processing Record 30 of Set 11 | scortaru nou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=scortaru%20nou
# Processing Record 31 of Set 11 | amboasary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=amboasary
# Processing Record 32 of Set 11 | mangan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mangan
# Processing Record 33 of Set 11 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=beringovskiy
# Processing Record 34 of Set 11 | lixourion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lixourion
# Processing Record 35 of Set 11 | minab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=minab
# Processing Record 36 of Set 11 | turayf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=turayf
# Processing Record 37 of Set 11 | wilmington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=wilmington
# Processing Record 38 of Set 11 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cockburn%20town
# Processing Record 39 of Set 11 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ambilobe
# Processing Record 40 of Set 11 | boyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=boyolangu
# Processing Record 41 of Set 11 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=quatre%20cocos
# Processing Record 42 of Set 11 | manjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=manjo
# Processing Record 43 of Set 11 | mrirt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mrirt
# City not found. Skipping...
# Processing Record 44 of Set 11 | loreto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=loreto
# Processing Record 45 of Set 11 | osmena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=osmena
# Processing Record 46 of Set 11 | fasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=fasa
# Processing Record 47 of Set 11 | kuryk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kuryk
# Processing Record 48 of Set 11 | normandin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=normandin
# Processing Record 49 of Set 11 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tual
# Processing Record 0 of Set 12 | palu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=palu
# Processing Record 1 of Set 12 | ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ballina
# Processing Record 2 of Set 12 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=constitucion
# Processing Record 3 of Set 12 | fengzhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=fengzhen
# Processing Record 4 of Set 12 | miles city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=miles%20city
# Processing Record 5 of Set 12 | barroualie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=barroualie
# City not found. Skipping...
# Processing Record 6 of Set 12 | northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=northam
# Processing Record 7 of Set 12 | roma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=roma
# Processing Record 8 of Set 12 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=grand%20gaube
# Processing Record 9 of Set 12 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=eureka
# Processing Record 10 of Set 12 | lawrenceburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lawrenceburg
# Processing Record 11 of Set 12 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=coihaique
# Processing Record 12 of Set 12 | russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=russell
# Processing Record 13 of Set 12 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=oranjemund
# Processing Record 14 of Set 12 | vawkavysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vawkavysk
# Processing Record 15 of Set 12 | nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nyurba
# Processing Record 16 of Set 12 | carndonagh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=carndonagh
# Processing Record 17 of Set 12 | derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=derzhavinsk
# Processing Record 18 of Set 12 | massakory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=massakory
# Processing Record 19 of Set 12 | bang saphan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bang%20saphan
# Processing Record 20 of Set 12 | bukama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bukama
# Processing Record 21 of Set 12 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=muros
# Processing Record 22 of Set 12 | zeya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=zeya
# Processing Record 23 of Set 12 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kutum
# Processing Record 24 of Set 12 | ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ayan
# Processing Record 25 of Set 12 | seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=seoul
# Processing Record 26 of Set 12 | felidhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=felidhoo
# City not found. Skipping...
# Processing Record 27 of Set 12 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=praia%20da%20vitoria
# Processing Record 28 of Set 12 | bograd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bograd
# Processing Record 29 of Set 12 | san andres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=san%20andres
# Processing Record 30 of Set 12 | kunming
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kunming
# Processing Record 31 of Set 12 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mount%20gambier
# Processing Record 32 of Set 12 | kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kiunga
# Processing Record 33 of Set 12 | felanitx
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=felanitx
# Processing Record 34 of Set 12 | satara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=satara
# Processing Record 35 of Set 12 | tocopilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tocopilla
# Processing Record 36 of Set 12 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=yar-sale
# Processing Record 37 of Set 12 | naron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=naron
# Processing Record 38 of Set 12 | dire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dire
# Processing Record 39 of Set 12 | susangerd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=susangerd
# Processing Record 40 of Set 12 | kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kenai
# Processing Record 41 of Set 12 | sterling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sterling
# Processing Record 42 of Set 12 | bargal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bargal
# City not found. Skipping...
# Processing Record 43 of Set 12 | altay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=altay
# Processing Record 44 of Set 12 | nalut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nalut
# Processing Record 45 of Set 12 | martinsville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=martinsville
# Processing Record 46 of Set 12 | nosy varika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nosy%20varika
# Processing Record 47 of Set 12 | san jose poaquil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=san%20jose%20poaquil
# Processing Record 48 of Set 12 | andselv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=andselv
# City not found. Skipping...
# Processing Record 49 of Set 12 | antsohihy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=antsohihy
# Processing Record 0 of Set 13 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bandarbeyla
# Processing Record 1 of Set 13 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=berlevag
# Processing Record 2 of Set 13 | caracuaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=caracuaro
# Processing Record 3 of Set 13 | sao francisco de paula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sao%20francisco%20de%20paula
# Processing Record 4 of Set 13 | juchen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=juchen
# Processing Record 5 of Set 13 | porangatu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=porangatu
# Processing Record 6 of Set 13 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=te%20anau
# Processing Record 7 of Set 13 | bantry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bantry
# City not found. Skipping...
# Processing Record 8 of Set 13 | mocambique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mocambique
# City not found. Skipping...
# Processing Record 9 of Set 13 | kuche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kuche
# City not found. Skipping...
# Processing Record 10 of Set 13 | mount pleasant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mount%20pleasant
# Processing Record 11 of Set 13 | ambatofinandrahana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ambatofinandrahana
# Processing Record 12 of Set 13 | nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nizwa
# Processing Record 13 of Set 13 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-augustin
# Processing Record 14 of Set 13 | acajutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=acajutla
# Processing Record 15 of Set 13 | muhldorf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=muhldorf
# Processing Record 16 of Set 13 | fomboni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=fomboni
# Processing Record 17 of Set 13 | wenling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=wenling
# Processing Record 18 of Set 13 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=maceio
# Processing Record 19 of Set 13 | dalaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dalaba
# Processing Record 20 of Set 13 | zenzeli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=zenzeli
# Processing Record 21 of Set 13 | bayanday
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bayanday
# Processing Record 22 of Set 13 | uwayl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=uwayl
# City not found. Skipping...
# Processing Record 23 of Set 13 | camargo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=camargo
# Processing Record 24 of Set 13 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kudahuvadhoo
# Processing Record 25 of Set 13 | kaitong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kaitong
# Processing Record 26 of Set 13 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 13 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=college
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 64.86, 'lon': -147.8},
#  'dt': 1532555880,
#  'id': 5859699,
#  'main': {'humidity': 31,
#   'pressure': 1018,
#   'temp': 77.54,
#   'temp_max': 78.8,
#   'temp_min': 75.2},
#  'name': 'College',
#  'sys': {'country': 'US',
#   'id': 63,
#   'message': 0.006,
#   'sunrise': 1532521828,
#   'sunset': 1532589737,
#   'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#    'icon': '04d',
#    'id': 803,
#    'main': 'Clouds'}],
#  'wind': {'deg': 220, 'speed': 4.7}}

# %%
city_data_pd = pd.DataFrame(city_data)
city_data_pd.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          hobart          75      AU  1532556000        61 -42.88  147.33
# 1      caluquembe           0      AO  1532558444        64 -13.78   14.68
# 2           kapaa           1      US  1532555760        66  22.08 -159.32
# 3  saint-philippe          90      CA  1532556900       100  45.36  -73.48
# 4         qaanaaq          32      GL  1532558445        90  77.48  -69.36
#
#    Max Temp  Wind Speed
# 0     48.20       12.75
# 1     45.83        5.19
# 2     84.20       13.87
# 3     80.60        5.82
# 4     37.82        0.94

# %%
lats = city_data_pd['Lat']
max_temps = city_data_pd['Max Temp']
humidity = city_data_pd['Humidity']
cloudiness = city_data_pd['Cloudiness']
windspeed = city_data_pd['Wind Speed']

city_data_pd.to_csv(output_data_file, index_label='City_Data')

city_data_pd.count()
# Out:
# City          564
# Cloudiness    564
# Country       564
# Date          564
# Humidity      564
# Lat           564
# Lng           564
# Max Temp      564
# Wind Speed    564
# dtype: int64

# %%
#create scatter plot for Temperature (F) vs. Latitude
plt.scatter(lats, max_temps, edgecolor='blue', linewidths=1,marker='o',
           alpha=0.9, label='Cities')

plt.title('City Latitude vs. Max Temperture (%s)'% time.strftime('%x'))
plt.ylabel('Max Temperture(F)')
plt.xlabel('Latitude')
plt.grid()

plt.savefig('output_data/Fig1.png')

plt.show()

# %%
# Humidity (%) vs. Latitude

plt.scatter(lats, humidity, edgecolor='blue', linewidths=1,marker='o',
           alpha=0.9, label='Cities')

plt.title('City Latitude vs. Humidity (%s)'% time.strftime('%x'))
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.ylim(ymax=120)
plt.grid()

plt.savefig('output_data/Fig2.png')

plt.show()

# %%
# Cloudiness (%) vs. Latitude
plt.scatter(lats, cloudiness,edgecolor='blue', linewidths=1,marker='o',
           alpha=0.9, label='Cities')
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime('%x'))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.grid()
plt.savefig('output_data/Fig3.png')

plt.show()

# %%
# Wind Speed (mph) vs. Latitude
plt.scatter(lats,windspeed,edgecolor='blue', linewidths=1,marker='o',
           alpha=0.9, label='Cities')

plt.title('City Latitude vs. Wind Speed (%s)'% time.strftime('%x'))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.grid()

plt.savefig('output_data/Fig4.png')

plt.show()
